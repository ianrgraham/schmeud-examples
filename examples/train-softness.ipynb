# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gc

# %%
df = pd.read_feather("../training.feather")

# %%
new_df = df[df["frame"] == 0]
del df

# %%
gc.collect()
# Out:
# 235

# %%
phop_desc = new_df.describe()["phop"]

# %%
new_df.hist("phop", bins=np.geomspace(phop_desc["min"], phop_desc["max"], 100))
plt.xscale('log')
